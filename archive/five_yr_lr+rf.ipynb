# %% [markdown]
# **Logistic Regression**

# %%
# Data Manipulation
import numpy as np
import pandas as pd
from datetime import datetime

# Plotting graphs
import matplotlib.pyplot as plt

# Machine learning
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

from ta import add_all_ta_features #pip install --upgrade ta https://github.com/bukosabino/ta https://medium.datadriveninvestor.com/predicting-the-stock-market-with-python-bba3cf4c56ef
from fastai.tabular.all import add_datepart #pip install fastai https://docs.fast.ai/tabular.core.html https://www.analyticsvidhya.com/blog/2018/10/predicting-stock-pri

# %% [markdown]
# 1. LR without technical features

# %%
df = pd.read_csv('data/AAPL_data.csv')
df.dropna()
df
# Out:
#             Date        High         Low        Open       Close       Volume  \
# 0     2017-04-28   36.075001   35.817501   36.022499   35.912498   83441600.0
# 1     2017-05-01   36.799999   36.240002   36.275002   36.645000  134411600.0
# 2     2017-05-02   37.022499   36.709999   36.884998   36.877499  181408800.0
# 3     2017-05-03   36.872501   36.067501   36.397499   36.764999  182788000.0
# 4     2017-05-04   36.785000   36.452499   36.630001   36.632500   93487600.0
# ...          ...         ...         ...         ...         ...          ...
# 1255  2022-04-22  167.869995  161.500000  166.460007  161.789993   84775200.0
# 1256  2022-04-25  163.169998  158.460007  161.119995  162.880005   96046400.0
# 1257  2022-04-26  162.339996  156.720001  162.250000  156.800003   95623200.0
# 1258  2022-04-27  159.789993  155.380005  155.910004  156.570007   88063200.0
# 1259  2022-04-28  164.520004  158.929993  159.250000  163.639999  115586400.0
#
#        Adj Close
# 0      33.907143
# 1      34.598736
# 2      34.818253
# 3      34.712040
# 4      34.586937
# ...          ...
# 1255  161.789993
# 1256  162.880005
# 1257  156.800003
# 1258  156.570007
# 1259  163.639999
#
# [1260 rows x 7 columns]

# %%
X = df[['High', 'Low', 'Open']]
y = np.where(df['Close'].shift(-1) > df['Close'], 1, -1)

# %%
split = int(0.8 * len(df))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

# %%
print(len(X_train), len(X_test))
# Out:
# 1008 252

# %%
model = LogisticRegression(max_iter=float('inf'))
model = model.fit(X_train, y_train)

# %%
model.score(X_test, y_test)
# Out:
# 0.5317460317460317

# %% [markdown]
# 2. LR with selected technical features

# %%
df = pd.read_csv('data/AAPL_data.csv')
df.dropna()
# Out:
#             Date        High         Low        Open       Close       Volume  \
# 0     2017-04-28   36.075001   35.817501   36.022499   35.912498   83441600.0
# 1     2017-05-01   36.799999   36.240002   36.275002   36.645000  134411600.0
# 2     2017-05-02   37.022499   36.709999   36.884998   36.877499  181408800.0
# 3     2017-05-03   36.872501   36.067501   36.397499   36.764999  182788000.0
# 4     2017-05-04   36.785000   36.452499   36.630001   36.632500   93487600.0
# ...          ...         ...         ...         ...         ...          ...
# 1255  2022-04-22  167.869995  161.500000  166.460007  161.789993   84775200.0
# 1256  2022-04-25  163.169998  158.460007  161.119995  162.880005   96046400.0
# 1257  2022-04-26  162.339996  156.720001  162.250000  156.800003   95623200.0
# 1258  2022-04-27  159.789993  155.380005  155.910004  156.570007   88063200.0
# 1259  2022-04-28  164.520004  158.929993  159.250000  163.639999  115586400.0
#
#        Adj Close
# 0      33.907143
# 1      34.598736
# 2      34.818253
# 3      34.712040
# 4      34.586937
# ...          ...
# 1255  161.789993
# 1256  162.880005
# 1257  156.800003
# 1258  156.570007
# 1259  163.639999
#
# [1260 rows x 7 columns]

# %%
df["Date"]=pd.to_datetime(df.Date, format="%Y-%m-%d")
df.index=df['Date']
data = df.sort_index(ascending=True, axis=0)
add_datepart(df, 'Date', drop=False)
df.drop('Elapsed', axis=1, inplace=True)
df
# Out:
#                  Date        High         Low        Open       Close  \
# Date
# 2017-04-28 2017-04-28   36.075001   35.817501   36.022499   35.912498
# 2017-05-01 2017-05-01   36.799999   36.240002   36.275002   36.645000
# 2017-05-02 2017-05-02   37.022499   36.709999   36.884998   36.877499
# 2017-05-03 2017-05-03   36.872501   36.067501   36.397499   36.764999
# 2017-05-04 2017-05-04   36.785000   36.452499   36.630001   36.632500
# ...               ...         ...         ...         ...         ...
# 2022-04-22 2022-04-22  167.869995  161.500000  166.460007  161.789993
# 2022-04-25 2022-04-25  163.169998  158.460007  161.119995  162.880005
# 2022-04-26 2022-04-26  162.339996  156.720001  162.250000  156.800003
# 2022-04-27 2022-04-27  159.789993  155.380005  155.910004  156.570007
# 2022-04-28 2022-04-28  164.520004  158.929993  159.250000  163.639999
#
#                  Volume   Adj Close  Year  Month  Week  Day  Dayofweek  \
# Date
# 2017-04-28   83441600.0   33.907143  2017      4    17   28          4
# 2017-05-01  134411600.0   34.598736  2017      5    18    1          0
# 2017-05-02  181408800.0   34.818253  2017      5    18    2          1
# 2017-05-03  182788000.0   34.712040  2017      5    18    3          2
# 2017-05-04   93487600.0   34.586937  2017      5    18    4          3
# ...                 ...         ...   ...    ...   ...  ...        ...
# 2022-04-22   84775200.0  161.789993  2022      4    16   22          4
# 2022-04-25   96046400.0  162.880005  2022      4    17   25          0
# 2022-04-26   95623200.0  156.800003  2022      4    17   26          1
# 2022-04-27   88063200.0  156.570007  2022      4    17   27          2
# 2022-04-28  115586400.0  163.639999  2022      4    17   28          3
#
#             Dayofyear  Is_month_end  Is_month_start  Is_quarter_end  \
# Date
# 2017-04-28        118         False           False           False
# 2017-05-01        121         False            True           False
# 2017-05-02        122         False           False           False
# 2017-05-03        123         False           False           False
# 2017-05-04        124         False           False           False
# ...               ...           ...             ...             ...
# 2022-04-22        112         False           False           False
# 2022-04-25        115         False           False           False
# 2022-04-26        116         False           False           False
# 2022-04-27        117         False           False           False
# 2022-04-28        118         False           False           False
#
#             Is_quarter_start  Is_year_end  Is_year_start
# Date
# 2017-04-28             False        False          False
# 2017-05-01             False        False          False
# 2017-05-02             False        False          False
# 2017-05-03             False        False          False
# 2017-05-04             False        False          False
# ...                      ...          ...            ...
# 2022-04-22             False        False          False
# 2022-04-25             False        False          False
# 2022-04-26             False        False          False
# 2022-04-27             False        False          False
# 2022-04-28             False        False          False
#
# [1260 rows x 19 columns]

# %%
df = add_all_ta_features(
    df, high="High", low="Low", open="Open", close="Close", volume="Volume")
# Out:
# c:\Users\Maggie Chen\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# c:\Users\Maggie Chen\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)

# %%
selected_features = ['trend_sma_fast', 'trend_ema_fast', 'momentum_stoch_rsi_k', 'momentum_stoch_rsi_d', 'momentum_rsi', \
                    'trend_macd', 'momentum_wr', 'volume_adi', 'momentum_roc', 'volume_obv', \
                    'volatility_bbh', 'volatility_bbl']
basic_features = ['High', 'Low', 'Open', 'Volume', 'Year', 'Month', 'Week', 'Day', 'Dayofweek']

# %% [markdown]
# **Notice here we need to deal with a lot of missing values**
# - filled as 0 for now - can discuss later

# %%
for col, _ in df.iteritems():
    df[col] = df[col].fillna(0)
X = df[selected_features + basic_features]
y = np.where(df['Close'].shift(-1) > df['Close'], 1, -1)

# %%
split = int(0.8 * len(df))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

# %%
print(len(X_train), len(X_test))
# Out:
# 1008 252

# %%
model = LogisticRegression(max_iter=float('inf'))
model = model.fit(X_train, y_train)

# %%
model.score(X_test, y_test)
# Out:
# 0.5515873015873016

# %% [markdown]
# 3. LR with full set of features

# %%
X = df.drop(['Close', 'trend_psar_down', 'trend_psar_up', 'Date', 'Adj Close'], axis=1)

# %%
split = int(0.8 * len(df))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

# %%
model = LogisticRegression(max_iter=float('inf'))
model = model.fit(X_train, y_train)

# %%
model.score(X_test, y_test)
# Out:
# 0.5079365079365079

# %% [markdown]
# **Ensemble Methods**
# - note: currently the code is not using cv for ensemble methods since we have a larger dataset - can discuss later

# %% [markdown]
# 1. APPLE

# %%
df = pd.read_csv('data/AAPL_data.csv')
df.dropna()
# Out:
#             Date        High         Low        Open       Close       Volume  \
# 0     2017-04-28   36.075001   35.817501   36.022499   35.912498   83441600.0
# 1     2017-05-01   36.799999   36.240002   36.275002   36.645000  134411600.0
# 2     2017-05-02   37.022499   36.709999   36.884998   36.877499  181408800.0
# 3     2017-05-03   36.872501   36.067501   36.397499   36.764999  182788000.0
# 4     2017-05-04   36.785000   36.452499   36.630001   36.632500   93487600.0
# ...          ...         ...         ...         ...         ...          ...
# 1255  2022-04-22  167.869995  161.500000  166.460007  161.789993   84775200.0
# 1256  2022-04-25  163.169998  158.460007  161.119995  162.880005   96046400.0
# 1257  2022-04-26  162.339996  156.720001  162.250000  156.800003   95623200.0
# 1258  2022-04-27  159.789993  155.380005  155.910004  156.570007   88063200.0
# 1259  2022-04-28  164.520004  158.929993  159.250000  163.639999  115586400.0
#
#        Adj Close
# 0      33.907143
# 1      34.598736
# 2      34.818253
# 3      34.712040
# 4      34.586937
# ...          ...
# 1255  161.789993
# 1256  162.880005
# 1257  156.800003
# 1258  156.570007
# 1259  163.639999
#
# [1260 rows x 7 columns]

# %%
df["Date"]=pd.to_datetime(df.Date, format="%Y-%m-%d")
df.index=df['Date']
data = df.sort_index(ascending=True, axis=0)
add_datepart(df, 'Date', drop=False)
df.drop('Elapsed', axis=1, inplace=True)
df
# Out:
#                  Date        High         Low        Open       Close  \
# Date
# 2017-04-28 2017-04-28   36.075001   35.817501   36.022499   35.912498
# 2017-05-01 2017-05-01   36.799999   36.240002   36.275002   36.645000
# 2017-05-02 2017-05-02   37.022499   36.709999   36.884998   36.877499
# 2017-05-03 2017-05-03   36.872501   36.067501   36.397499   36.764999
# 2017-05-04 2017-05-04   36.785000   36.452499   36.630001   36.632500
# ...               ...         ...         ...         ...         ...
# 2022-04-22 2022-04-22  167.869995  161.500000  166.460007  161.789993
# 2022-04-25 2022-04-25  163.169998  158.460007  161.119995  162.880005
# 2022-04-26 2022-04-26  162.339996  156.720001  162.250000  156.800003
# 2022-04-27 2022-04-27  159.789993  155.380005  155.910004  156.570007
# 2022-04-28 2022-04-28  164.520004  158.929993  159.250000  163.639999
#
#                  Volume   Adj Close  Year  Month  Week  Day  Dayofweek  \
# Date
# 2017-04-28   83441600.0   33.907143  2017      4    17   28          4
# 2017-05-01  134411600.0   34.598736  2017      5    18    1          0
# 2017-05-02  181408800.0   34.818253  2017      5    18    2          1
# 2017-05-03  182788000.0   34.712040  2017      5    18    3          2
# 2017-05-04   93487600.0   34.586937  2017      5    18    4          3
# ...                 ...         ...   ...    ...   ...  ...        ...
# 2022-04-22   84775200.0  161.789993  2022      4    16   22          4
# 2022-04-25   96046400.0  162.880005  2022      4    17   25          0
# 2022-04-26   95623200.0  156.800003  2022      4    17   26          1
# 2022-04-27   88063200.0  156.570007  2022      4    17   27          2
# 2022-04-28  115586400.0  163.639999  2022      4    17   28          3
#
#             Dayofyear  Is_month_end  Is_month_start  Is_quarter_end  \
# Date
# 2017-04-28        118         False           False           False
# 2017-05-01        121         False            True           False
# 2017-05-02        122         False           False           False
# 2017-05-03        123         False           False           False
# 2017-05-04        124         False           False           False
# ...               ...           ...             ...             ...
# 2022-04-22        112         False           False           False
# 2022-04-25        115         False           False           False
# 2022-04-26        116         False           False           False
# 2022-04-27        117         False           False           False
# 2022-04-28        118         False           False           False
#
#             Is_quarter_start  Is_year_end  Is_year_start
# Date
# 2017-04-28             False        False          False
# 2017-05-01             False        False          False
# 2017-05-02             False        False          False
# 2017-05-03             False        False          False
# 2017-05-04             False        False          False
# ...                      ...          ...            ...
# 2022-04-22             False        False          False
# 2022-04-25             False        False          False
# 2022-04-26             False        False          False
# 2022-04-27             False        False          False
# 2022-04-28             False        False          False
#
# [1260 rows x 19 columns]

# %%
df = add_all_ta_features(
df, high="High", low="Low", open="Open", close="Close", volume="Volume")
selected_features = ['trend_sma_fast', 'trend_ema_fast', 'momentum_stoch_rsi_k', 'momentum_stoch_rsi_d', 'momentum_rsi', \
                'trend_macd', 'momentum_wr', 'volume_adi', 'momentum_roc', 'volume_obv', \
                'volatility_bbh', 'volatility_bbl']
basic_features = ['High', 'Low', 'Open', 'Volume', 'Year', 'Month', 'Week', 'Day', 'Dayofweek']
# Out:
# c:\Users\Maggie Chen\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# c:\Users\Maggie Chen\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)

# %%
for col, _ in df.iteritems():
    df[col] = df[col].fillna(0)
X = df[selected_features + basic_features]
y = np.where(df['Close'].shift(-1) > df['Close'], 1, -1)

# %%
split = int(0.8 * len(df))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

# %%
def random_forest(X_train, X_test, y_train, y_test):
    '''
    Run random forest and return model and accuracy score. 
    '''
    model = RandomForestClassifier(random_state=42, n_estimators=100)
    model.fit(X_train, y_train)
    return model, model.score(X_test, y_test), model.feature_importances_

# %%
def adaboost(X_train, X_test, y_train, y_test):
    '''
    Run adaboost and return model and accuracy score. 
    '''   
    model = AdaBoostClassifier(random_state=42, n_estimators=100)
    model.fit(X_train, y_train)
    return model, model.score(X_test, y_test), model.feature_importances_

# %%
def gradient_boost(X_train, X_test, y_train, y_test):
    '''
    Run gradient boosting and return model and accuracy score. 
    '''       
    model = GradientBoostingClassifier(random_state=42, n_estimators=100)
    model.fit(X_train, y_train)
    return model, model.score(X_test, y_test), model.feature_importances_

# %%
_, score_rf, fi_rf = random_forest(X_train, X_test, y_train, y_test)
print('random forest accuracy is, ', score_rf)
# Out:
# random forest accuracy is,  0.5079365079365079

# %%
_, score_ada, fi_ada = adaboost(X_train, X_test, y_train, y_test)
print('adaboosting accuracy is, ', score_ada)
# Out:
# adaboosting accuracy is,  0.5

# %%
_, score_gb, fi_gb = gradient_boost(X_train, X_test, y_train, y_test)
print('gradient boosting accuracy is, ', score_gb)
# Out:
# gradient boosting accuracy is,  0.5277777777777778
